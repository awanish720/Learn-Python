# %%
# Print Hello Word
print("Hello Word!")
# Out:
# Hello Word!

# %%
# Name Error
printt("Hello Python")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 printt("Hello Python")
#
# NameError: name 'printt' is not defined

# %%
# Dynamic Type
x = 10 # Integer
x = "Hello" # String
print(x)
type(x)
# Out:
# Hello
# str

# %%
# library

import math
print(math.sqrt(25))
# Out:
# 5.0

# %%
num1 = 5
num2 = 10
sum = num1 + num2

print("The sum is: ",sum)
# Out:
# The sum is:  15

# %%
## Case Sensitivity

name = "Awanish"
Name = "Raj"

print(name)
print(Name)
# Out:
# Awanish
# Raj

# %%
## Indentation

age = 32
if age > 30:
    print(age)
# Out:
# 32

# %%
'''This is a comment
written in python
more than one line

'''
print("Hii")
# Out:
# Hii

# %%
import keyword

print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', '__peg_parser__', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
# Local Variable
def my_fun():
    a = 10
    print(a)

my_fun()
# Out:
# 10

# %%
# Global variable
b = 30
def my_function():
    print(b)

my_function()
# Out:
# 30

# %%
# Global keyword

c = 50
def fun():
    global c
    print(c)

fun()
# Out:
# 50

# %%
# Type Conversion

age = 30
print(type(age))

age_str = str(age)
print(age_str)
print(type(age_str))
# Out:
# <class 'int'>
# 30
# <class 'str'>

# %%
# Syntax =>  print(*objects, sep=' ', end='\n', file=sys.stdout, flush=False)
import sys
print("Hello!","World!",123,sep='-',end='Python\n')
# Out:
# Hello!-World!-123Python

# %%
with open("output.txt","w") as f:
    print("Hello","World",file=f)

# %%
# Flush
import sys
import time

print("Loading", end=",",flush=True)
time.sleep(2)
print("Done")
# Out:
# Loading,Done
